# %%
from dataset import get_dataset, show_batch

trainX = get_dataset('data/butterfly_real/*.jpeg', batch_size=4)
trainY = get_dataset('data/butterfly_origami/*.jpg', batch_size=4)

show_batch(trainX)
show_batch(trainY)
